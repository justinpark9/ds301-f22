# %% [markdown]
# **DS 301: Applied Data Modeling and Predictive Analysis**
#
# # Lab 2 – Simple Linear Regression
#
# Justin Park, 14 September 2022
#
# **Credit:** https://github.com/asukul/DS301-f19/blob/master/Lab1_Simple-Linear-Regression_animal_Brain-BodySize_prediction.ipynb by Adisak Sukul

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

data_path = os.path.join("datasets", "brain-bodysize.csv")
df = pd.read_csv(data_path)
df.head(10)
# Out:
#      Brain   Body
# 0    3.385   44.5
# 1    0.480   15.5
# 2    1.350    8.1
# 3  465.000  423.0
# 4   36.330  119.5
# 5   27.660  115.0
# 6   14.830   98.2
# 7    1.040    5.5
# 8    4.190   58.0
# 9    0.425    6.4

# %%
x= df[['Brain']]
y= df[['Body']]

df
# Out:
#       Brain     Body
# 0     3.385    44.50
# 1     0.480    15.50
# 2     1.350     8.10
# 3   465.000   423.00
# 4    36.330   119.50
# 5    27.660   115.00
# 6    14.830    98.20
# 7     1.040     5.50
# 8     4.190    58.00
# 9     0.425     6.40
# 10    0.101     4.00
# 11    0.920     5.70
# 12    1.000     6.60
# 13    0.005     0.14
# 14    0.060     1.00
# 15    3.500    10.80
# 16    2.000    12.30
# 17    1.700     6.30
# 18    0.023     0.30
# 19  187.100   419.00
# 20  521.000   655.00
# 21    0.785     3.50
# 22   10.000   115.00
# 23    3.300    25.60
# 24    0.200     5.00
# 25    1.410    17.50
# 26  529.000   680.00
# 27  207.000   406.00
# 28   85.000   325.00
# 29    0.750    12.30
# 30   62.000  1320.00
# 31    3.500     3.90
# 32    6.800   179.00
# 33   35.000    56.00
# 34    4.050    17.00
# 35    0.120     1.00
# 36    0.023     0.40
# 37    0.010     0.25
# 38    1.400    12.50
# 39  250.000   490.00
# 40    2.500    12.10
# 41   55.500   175.00
# ...

# %% [markdown]
# **Task 1:** Use scikit-learn to train your model with LinearRegression. [3 points]

# %%
lin_reg = LinearRegression()
lrModel = lin_reg.fit(x, y)

# %% [markdown]
# **Task 2:** Use matplotlib (or any visualization libraries) to visualize the data. Also, add your regression line to your plot. [3 points]

# %%
prediction = lrModel.predict(x)
plt.plot(x, prediction, label = 'Linear Regression', color = 'b')
plt.scatter(x, y, label = 'Training Data', color = 'g', alpha = .7)
plt.legend()
plt.title("Training Data Set and Linear Regression Line")
plt.xlabel("Brain")
plt.ylabel("Body")
plt.show()

# %% [markdown]
# **Task 3:** Create three different new unseen data points (Xs) and make predictions from your model (Ys) [4 points]

# %%
#Testing X values of 300, 350, and 400. Getting a warning. Not sure how to fix this.
y1 = lrModel.predict(np.array([[300]]))[0]
y2 = lrModel.predict(np.array([[350]]))[0]
y3 = lrModel.predict(np.array([[400]]))[0]
print(y1, y2, y3)
# Out:
# [428.76568552] [490.90132357] [553.03696163]
# C:\Users\Justin Park\anaconda3\envs\ds301\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Justin Park\anaconda3\envs\ds301\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Justin Park\anaconda3\envs\ds301\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Bonus:** Explain possible techniques to improve the accuracy of this model. [2 points]

# %% [markdown]
# One way to improve the accuracy of the model is to delete the outliers. There is a point towards the top of the plot above 1200 that may be skewing the linear line in that direction. I would keep all the points that are close to the linear line.
